# %%
# In your Jupyter notebook, run this to see actual RAM used:
import psutil
import os

process = psutil.Process(os.getpid())
print(f"Actual RAM used: {process.memory_info().rss / 1024**2:.2f} MB")
# Out:
# Actual RAM used: 27.70 MB
